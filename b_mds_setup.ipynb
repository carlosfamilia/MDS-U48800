# %% [markdown]
# ## U-48800

# %% [markdown]
# ### Molecular dynamics simulation

# %% [markdown]
# #### Environment setup

# %%
# Define imports
import re
import os
import sys
import subprocess
print("Python version: ", sys. version)

import numpy as np
print("Numpy version: ", np.__version__)

import seaborn as sns
print("Seaborn version: ", sns.__version__)

import matplotlib
import matplotlib.pyplot as plt
print("Matplotlib version: ", matplotlib.__version__)
# Out:
# Python version:  3.12.3 (main, Apr 12 2024, 17:28:17) [Clang 13.0.0 (clang-1300.0.29.3)]
# Numpy version:  1.26.4
# Seaborn version:  0.13.2
# Matplotlib version:  3.8.4

# %%
# Set the working directory and change folder to it
working_dir = '~/research/synthetic_opioids'
os.chdir(working_dir)

# Import glx auxiliary functions
from gmx import gmx, xvg

# %%
# Set molecule path, molecule filename and molecular dynamics directory path
compound = "U48800"
mdscmode = "rest"
solvent = "water"

# Parameters
replicas = 10
tmin = 293.15
tmax = 573.15

# %%
# Set paths
basepath = "%s/%s/%s" % (compound, mdscmode, solvent)
parapath = "%s/%s/parameters" % (compound, mdscmode)
origpath = "%s/%s/original" % (compound, mdscmode)
libppath = "%s/%s/ligpargen" % (compound, mdscmode)

# %%
# Set temperature values for replica exchange molecular dynamics (https://www.plumed.org/doc-v2.9/user-doc/html/hrex.html)
# Adjusting the previous code to round the temperatures to 2 decimal places
temperature_value = [round(tmin * np.exp(i * np.log(tmax / tmin) / (replicas - 1)), 2) for i in range(replicas)]

# Print the list
print("Temperatures:", temperature_value)

# Compute lambda values
lambda_value = [1.0000] + [round(x, 3) for x in temperature_value[0] / temperature_value[1:]]
print("Lambda values:", lambda_value)

# Compute kappa values
kappa_value = [round(0.916248 + 0.0002857 * x, 3) for x in temperature_value]
print("Kappa values:", kappa_value)
# Out:
# Temperatures: [293.15, 315.82, 340.25, 366.56, 394.91, 425.46, 458.36, 493.81, 532.0, 573.15]
# Lambda values: [1.0, 0.928, 0.862, 0.8, 0.742, 0.689, 0.64, 0.594, 0.551, 0.511]
# Kappa values: [1.0, 1.006, 1.013, 1.021, 1.029, 1.038, 1.047, 1.057, 1.068, 1.08]

# %%
# Create the molecular dynamics directory if it does not exist
os.makedirs(basepath, exist_ok = True)

# Create the directory to store all original input files for the simulation
os.makedirs(origpath, exist_ok = True)

# Create the molecular dynamics parameters directory if it does not exist
os.makedirs(parapath, exist_ok = True)

# Create the directory ligpargen output if it does not exist
os.makedirs(libppath, exist_ok = True)

# Delete all files in the molecular dynamics directory
files = [file for file in os.listdir(basepath) if os.path.isfile(os.path.join(basepath, file))]
for file in files:
    os.remove("%s/%s" % (basepath, file))

# %% [markdown]
# #### Simulation setup

# %% [markdown]
# LigParGen (https://traken.chem.yale.edu/ligpargen/ (https://doi.org/10.1073/pnas.0408037102, https://doi.org/10.1021/acs.jpcb.7b00272, https://doi.org/10.1093/nar/gkx312)) was used to generate the force field (OPLS-AA) parameters for U-48800 based on the PDB file. This resulted in three files, the force field definition file (U48800.itp), the topology file (U48800.top), and the gromacs structure file (U48800.gro), required for molecular dynamics simulations with gromacs.
# Note that the U48800.top file was edited to have the information from the forcefield for the solute (U48800.itp) and water tip4p.itp from OPLS-AA.

# %%
# Copy the molecule force field and structure files to the molecular dynamics directory from ligpargen output zip file
os.system("cp %s/%s.itp %s" % (libppath, compound, origpath))
os.system("cp %s/%s.gro %s" % (libppath, compound, origpath))
os.system("cp %s/%s.top %s" % (libppath, compound, origpath))
# Out:
# 0

# %%
# Copy the required files to the molecular dynamics directory
os.system("cp %s/*.pdb %s/" % (compound, origpath))
os.system("cp %s/* %s/" % (origpath, basepath))
# Out:
# 0

# %%
# Define the box shape and size
gmx(
    executable = "editconf",
    arguments = [
        "-bt", "cubic",                # Box type
        "-d", "1.0",                   # Distance between solute and box edge
        "-c"                           # Center the molecule
    ],
    inputs = {
        "-f": "%s.gro" % compound      # Input structure file
    },
    outputs = {
        "-o": "%s.gro" % compound      # Output structure file
    },
    path = "%s" % (basepath)
)
# Out:
# Note that major changes are planned in future for editconf, to improve usability and utility.
# Read 46 atoms
# Volume: 1 nm^3, corresponds to roughly 400 electrons
# No velocities found
#     system size :  0.695  0.964  0.901 (nm)
#     diameter    :  1.155               (nm)
#     center      :  0.050  0.135 -0.031 (nm)
#     box vectors :  1.000  1.000  1.000 (nm)
#     box angles  :  90.00  90.00  90.00 (degrees)
#     box volume  :   1.00               (nm^3)
#     shift       :  1.528  1.443  1.608 (nm)
# new center      :  1.577  1.577  1.577 (nm)
# new box vectors :  3.155  3.155  3.155 (nm)
# new box angles  :  90.00  90.00  90.00 (degrees)
# new box volume  :  31.40               (nm^3)
#
#             :-) GROMACS - gmx editconf, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water
# Command line:
#   gmx editconf -bt cubic -d 1.0 -c -f U48800.gro -o U48800.gro
#
#
# Back Off! I just backed up U48800.gro to ./#U48800.gro.1#
#
# GROMACS reminds you: "I removed all the lambda defaults so that users have to think!" (Berk Hess)

# %%
# Define the water model and solvate the system
gmx(
    executable = "solvate",
    arguments = [
        "-cs", "tip4p"                  # Water model
    ],
    inputs = {
        "-cp": "%s.gro" % compound,     # Input structure file
        "-p":  "%s.top" % compound      # Topology file
    },
    outputs = {
        "-o": "%s.gro" % compound       # Output structure file
    },
    path = "%s" % (basepath)
)
# Out:
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx solvate uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. 68 (1964) pp. 441-451
# -------- -------- --- Thank You --- -------- --------
#
# Adding line for 1018 solvent molecules with resname (SOL) to topology file (U48800.top)
#
#             :-) GROMACS - gmx solvate, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water
# Command line:
#   gmx solvate -cs tip4p -cp U48800.gro -p U48800.top -o U48800.gro
#
# Reading solute configuration
# Reading solvent configuration
#
# Initialising inter-atomic distances...
# Generating solvent configuration
# Will generate new solvent configuration of 2x2x2 boxes
# Solvent box contains 5536 atoms in 1384 residues
# Removed 1400 solvent atoms due to solvent-solvent overlap
# Removed 64 solvent atoms due to solute-solvent overlap
# Sorting configuration
# Found 1 molecule type:
#     SOL (   4 atoms):  1018 residues
# Generated solvent containing 4072 atoms in 1018 residues
# Writing generated configuration to U48800.gro
#
# Back Off! I just backed up U48800.gro to ./#U48800.gro.2#
#
# Output configuration contains 4118 atoms in 1019 residues
# Volume                 :     31.4049 (nm^3)
# Density                :      987.97 (g/l)
# Number of solvent molecules:   1018
#
# Processing topology
#
# Back Off! I just backed up U48800.top to ./#U48800.top.1#
#
# GROMACS reminds you: "I removed all the lambda defaults so that users have to think!" (Berk Hess)

# %% [markdown]
# #### Minimisation

# %%
# Prepare the system for minimization
ensemble = "min"

# Copy the parameter file to the directory
os.system("cp %s/%s.mdp %s" % (parapath, ensemble, basepath))

gmx(
    executable = "grompp",
    arguments = [
        "-maxwarn", "2"                    # Maximum number of warnings (there is a warning relative to charge)
    ],
    inputs = {
        "-f": "%s.mdp" % ensemble,  # Minimization parameters file
        "-c": "%s.gro" % compound,         # Input structure file
        "-p": "%s.top" % compound          # Topology file
    },
    outputs = {
        "-po": "%s.mdp" % ensemble,                  # Output parameters file
        "-pp": "%s.top" % ensemble,                  # Output topology file
        "-o" : "%s.tpr" % ensemble                  # Output portable xdr run input file
    },
    path = "%s" % (basepath)
)
# Out:
# Setting the LD random seed to -59049240
#
# Generated 1225 of the 1225 non-bonded parameter combinations
#
# Generated 1225 of the 1225 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'SOP'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:     1      Other residues
# There are:  1018      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# The largest distance between excluded atoms is 0.403 nm between atom 20 and 22
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.113 0.113 0.113
#
# Estimate for the relative computational load of the PME mesh part: 0.12
#
# This run will generate roughly 54 Mb of data
#
#              :-) GROMACS - gmx grompp, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water
# Command line:
#   gmx grompp -maxwarn 2 -f ../parameters/min.mdp -c U48800.gro -p U48800.top -po min.mdp -pp min.top -o min.tpr
#
# Generating 1-4 interactions: fudge = 0.5
#
# NOTE 1 [file U48800.top, line 17]:
#   System has non-zero total charge: 0.000400
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 1 [file U48800.top, line 17]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
# Number of degrees of freedom in T-Coupling group rest is 7237.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "Sincerity is the key to success. Once you can fake that you've got it made." (Groucho Marx)

# %%
# Run the simulation
gmx(
    executable = "mdrun",
    ensemble = ensemble,
    arguments = [
        "-v",                                   # Verbose output
        "-deffnm", ensemble,                    # Input and output file name prefix
        "-dlb", "auto"                          # Dynamic load balancing auto
    ],
    inputs = {},
    outputs = {}, 
    name = compound,
    path = basepath, 
    wait = True
)
# Out:
# Submitted batch job 386

# %%
# Generate the pressure xvg file
measure = 11 # Potential energy

gmx(
    executable = "energy",
    arguments = [],
    inputs = {
        "-f": "%s.edr" % ensemble
    },
    outputs = {
        "-o": "%s.xvg" % ensemble
    },
    stdin = "%d 0\n" % measure, 
    path = "%s" % (basepath)
)

# Generate the display the corresponding plots
xvg(title = "Energy minimization",
    temperatures = temperature_value,
    path = basepath,
    ensemble = ensemble,
    xlabel = "Energy minimization step",
    ylabel = "Energy ($kJ\\cdot mol^{-1}$)",
    label = "Potential Energy",
    movavg = False
    )
# Out:
# Statistics over 10000 steps [ 0.0000 through 9999.0000 ps ], 1 data sets
# All statistics are over 7917 points (frames)
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Potential                  -50337.5        650    2022.51   -4186.16  (kJ/mol)
#
#              :-) GROMACS - gmx energy, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water
# Command line:
#   gmx energy -f min.edr -o min.xvg
#
# Opened min.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Pres.-DC
#  13  Pressure        14  Constr.-rmsd    15  Vir-XX          16  Vir-XY
#  17  Vir-XZ          18  Vir-YX          19  Vir-YY          20  Vir-YZ
#  21  Vir-ZX          22  Vir-ZY          23  Vir-ZZ          24  Pres-XX
#  25  Pres-XY         26  Pres-XZ         27  Pres-YX         28  Pres-YY
#  29  Pres-YZ         30  Pres-ZX         31  Pres-ZY         32  Pres-ZZ
#  33  #Surf*SurfTen   34  T-rest
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   19.000
# Reading energy frame     19 time   20.000
# Reading energy frame     20 time   21.000
# Reading energy frame     30 time   34.000
# Reading energy frame     40 time   47.000
# Reading energy frame     50 time   59.000
# Reading energy frame     60 time   72.000
# Reading energy frame     70 time   85.000
# Reading energy frame     80 time   98.000
# Reading energy frame     90 time  110.000
# Reading energy frame    100 time  123.000
# Reading energy frame    110 time  136.000
# Reading energy frame    120 time  148.000
# Reading energy frame    130 time  161.000
# Reading energy frame    140 time  174.000
# Reading energy frame    150 time  187.000
# Reading energy frame    160 time  199.000
# Reading energy frame    170 time  212.000
# Reading energy frame    180 time  224.000
# Reading energy frame    190 time  238.000
# Reading energy frame    200 time  250.000
# Reading energy frame    300 time  377.000
# Reading energy frame    400 time  503.000
# Reading energy frame    500 time  629.000
# Reading energy frame    600 time  757.000
# Reading energy frame    700 time  883.000
# Reading energy frame    800 time 1009.000
# Reading energy frame    900 time 1135.000
# Reading energy frame   1000 time 1262.000
# Reading energy frame   1100 time 1388.000
# Reading energy frame   1200 time 1515.000
# Reading energy frame   1300 time 1641.000
# Reading energy frame   1400 time 1767.000
# Reading energy frame   1500 time 1893.000
# Reading energy frame   1600 time 2020.000
# Reading energy frame   1700 time 2147.000
# Reading energy frame   1800 time 2272.000
# Reading energy frame   1900 time 2399.000
# Reading energy frame   2000 time 2525.000
# Reading energy frame   3000 time 3789.000
# Reading energy frame   4000 time 5052.000
# Reading energy frame   5000 time 6315.000
# Reading energy frame   6000 time 7579.000
# Reading energy frame   7000 time 8842.000
# Last energy frame read 7916 time 9999.000
#
# GROMACS reminds you: "We're having an information explosion, among others, and it's certainly obvious that information is of no use unless it's available." (Sister Mary Kenneth Keller)
# <table><td><img src="U48800/rest/water/min.png?1720126376.0551074" style="width:100%"></td></table>

# %%
# Backup all progress
os.makedirs("%s/../%s.back" % (basepath, solvent), exist_ok = True)
os.makedirs("%s/../%s.back/%s" % (basepath, solvent, ensemble), exist_ok = True)
os.system("cp -R %s/* %s/../%s.back/%s/" % (basepath, basepath, solvent, ensemble))
# Out:
# 0

# %% [markdown]
# #### NVT Equilibration

# %%
# Define the ensemble
presembl = "min" # Previous ensemble
ensemble = "nvt" # Ensemble

# Copy the parameter file to the work directory
os.system("cp %s/%s.mdp %s" % (parapath, ensemble, basepath))
    
gmx(
    executable = "grompp",
    arguments = [
        "-maxwarn", "2"                              # Maximum number of warnings (there is a warning relative to charge)
    ],
    inputs = {
        "-f": "%s.mdp" % ensemble,                   # Minimization parameters file
        "-c": "%s.gro" % presembl,                   # Input structure file
        "-p": "%s.top" % presembl                    # Topology file
    },
    outputs = {
        "-po": "%s.mdp" % ensemble,                  # Output parameters file
        "-pp": "%s.top" % ensemble,                  # Output topology file
        "-o" : "%s.tpr" % ensemble                   # Output portable xdr run input file
    },
    path = "%s" % (basepath)
)
# Out:
# Setting the LD random seed to -2097163
#
# Generated 1225 of the 1225 non-bonded parameter combinations
#
# Generated 1225 of the 1225 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'SOP'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
#
# Setting gen_seed to -101721282
#
# Velocities were taken from a Maxwell distribution at 293.15 K
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:     1      Other residues
# There are:  1018      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# The largest distance between excluded atoms is 0.405 nm between atom 20 and 22
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 293.15 K
#
# Calculated rlist for 1x1 atom pair-list as 1.213 nm, buffer size 0.013 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.113 0.113 0.113
#
# Estimate for the relative computational load of the PME mesh part: 0.09
#
# This run will generate roughly 15 Mb of data
#
#              :-) GROMACS - gmx grompp, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water
# Command line:
#   gmx grompp -maxwarn 2 -f nvt.mdp -c min.gro -p min.top -po nvt.mdp -pp nvt.top -o nvt.tpr
#
# Generating 1-4 interactions: fudge = 0.5
#
# NOTE 1 [file min.top, line 572]:
#   System has non-zero total charge: 0.000400
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 1 [file min.top, line 572]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
# Number of degrees of freedom in T-Coupling group System is 7237.00
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "Or (horrors!) use Berendsen!" (Justin Lemkul)

# %%
# Run the simulation
gmx(
    executable = "mdrun",
    ensemble = ensemble,
    arguments = [
        "-v",                                   # Verbose output
        "-deffnm", ensemble,                    # Input and output file name prefix
        "-dlb", "auto"                          # Dynamic load balancing auto
    ],
    inputs = {},
    outputs = {}, 
    name = compound,
    path = basepath, 
    wait = True
)
# Out:
# Submitted batch job 387

# %%
#Generate the temperature xvg file
measure = 15     # Temperature

# Compute the the selected parameter from the ensemble simulation
gmx(
    executable = "energy",
    arguments = [],
    inputs = {
        "-f": "%s.edr" % ensemble
    },
    outputs = {
        "-o": "%s.xvg" % ensemble
    },
    stdin = "%d 0\n" % measure, 
    path = "%s" % (basepath)
)

# Generate the display the corresponding plots
xvg(title = "NVT Equilibration",
    path = basepath,
    ensemble = ensemble,
    xlabel = "Time (ps)",
    ylabel = "Temperature (K)",
    label = "Temperature",
    movavg = 10
    )
# Out:
# Statistics over 100001 steps [ 0.0000 through 100.0000 ps ], 1 data sets
# All statistics are over 1001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                 292.846       0.34    6.44613    2.39328  (K)
#
#              :-) GROMACS - gmx energy, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water
# Command line:
#   gmx energy -f nvt.edr -o nvt.xvg
#
# Opened nvt.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Vir-XX          20  Vir-XY
#  21  Vir-XZ          22  Vir-YX          23  Vir-YY          24  Vir-YZ
#  25  Vir-ZX          26  Vir-ZY          27  Vir-ZZ          28  Pres-XX
#  29  Pres-XY         30  Pres-XZ         31  Pres-YX         32  Pres-YY
#  33  Pres-YZ         34  Pres-ZX         35  Pres-ZY         36  Pres-ZZ
#  37  #Surf*SurfTen   38  T-System        39  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Last energy frame read 100 time  100.000
#
# GROMACS reminds you: "Uh-oh, We're In Trouble" (Shampoo)
# <table><td><img src="U48800/rest/water/nvt.png?1720126995.0442045" style="width:100%"></td></table>

# %%
# Backup all progress
os.makedirs("%s/../%s.back" % (basepath, solvent), exist_ok = True)
os.makedirs("%s/../%s.back/%s" % (basepath, solvent, ensemble), exist_ok = True)
os.system("cp -R %s/* %s/../%s.back/%s/" % (basepath, basepath, solvent, ensemble))
# Out:
# 0

# %% [markdown]
# #### NPT Equilibration

# %%
# Define the ensemble
presembl = "nvt" # Previous ensemble
ensemble = "npt" # Ensemble

# Copy the parameter file to the work directory
os.system("cp %s/%s.mdp %s" % (parapath, ensemble, basepath))
    
gmx(
    executable = "grompp",
    arguments = [
        "-maxwarn", "2"                              # Maximum number of warnings (there is a warning relative to charge)
    ],
    inputs = {
        "-f": "%s.mdp" % ensemble,                   # Minimization parameters file
        "-c": "%s.gro" % presembl,                   # Input structure file
        "-p": "%s.top" % presembl                    # Topology file
    },
    outputs = {
        "-po": "%s.mdp" % ensemble,                  # Output parameters file
        "-pp": "%s.top" % ensemble,                  # Output topology file
        "-o" : "%s.tpr" % ensemble                   # Output portable xdr run input file
    },
    path = "%s" % (basepath)
)
# Out:
# Setting the LD random seed to -1211176135
#
# Generated 1225 of the 1225 non-bonded parameter combinations
#
# Generated 1225 of the 1225 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'SOP'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:     1      Other residues
# There are:  1018      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# The largest distance between excluded atoms is 0.403 nm between atom 20 and 22
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 293.15 K
#
# Calculated rlist for 1x1 atom pair-list as 1.213 nm, buffer size 0.013 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.113 0.113 0.113
#
# Estimate for the relative computational load of the PME mesh part: 0.09
#
# This run will generate roughly 15 Mb of data
#
#              :-) GROMACS - gmx grompp, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water
# Command line:
#   gmx grompp -maxwarn 2 -f npt.mdp -c nvt.gro -p nvt.top -po npt.mdp -pp npt.top -o npt.tpr
#
# Generating 1-4 interactions: fudge = 0.5
#
# NOTE 1 [file nvt.top, line 572]:
#   System has non-zero total charge: 0.000400
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 1 [file nvt.top, line 572]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
# Number of degrees of freedom in T-Coupling group System is 7237.00
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "Two chemists walk into a bar. The first one says, 'I'll have some H2O.'. The second one says, 'I'll have some H2O, too'. He dies." (Anonymous)

# %%
# Run the simulation
gmx(
    executable = "mdrun",
    ensemble = ensemble,
    arguments = [
        "-v",                                   # Verbose output
        "-deffnm", ensemble,                    # Input and output file name prefix
        "-dlb", "auto"                          # Dynamic load balancing auto
    ],
    inputs = {},
    outputs = {}, 
    name = compound,
    path = basepath, 
    wait = True
)
# Out:
# Submitted batch job 388

# %%
# Generate the pressure xvg file
measure = 17     # Pressure
sufix = "_p"

# Compute the the selected parameter from the ensemble simulation

gmx(
    executable = "energy",
    arguments = [],
    inputs = {
        "-f": "%s.edr" % ensemble
    },
    outputs = {
        "-o": "%s%s.xvg" % (ensemble, sufix)
    },
    stdin = "%d 0\n" % measure, 
    path = "%s" % (basepath)
)

# Generate the display the corresponding plots
xvg(title = "NPT Equilibration",
    path = basepath,
    ensemble = ensemble,
    xlabel = "Time (ps)",
    ylabel = "Pressure (bar)",
    label = "Pressure",
    sufix = sufix,
    movavg = 10
    )
# Out:
# Statistics over 100001 steps [ 0.0000 through 100.0000 ps ], 1 data sets
# All statistics are over 1001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                    -14.465         29    424.428   -12.7747  (bar)
#
#              :-) GROMACS - gmx energy, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water
# Command line:
#   gmx energy -f npt.edr -o npt_p.xvg
#
# Opened npt.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Last energy frame read 100 time  100.000
#
# GROMACS reminds you: "Ludwig Boltzmann, who spent much of his life studying statistical mechanics, died in 1906, by his own hand. Paul Ehrenfest, carrying on the same work, died similarly in 1933. Now it is our turn to study statistical mechanics. Perhaps it will be wise to approach the subject cautiously." (David Goodstein)
# <table><td><img src="U48800/rest/water/npt_p.png?1720127646.081533" style="width:100%"></td></table>

# %%
# Generate the density xvg file
measure = 23     # Density
sufix = "_d"

# Compute the the selected parameter from the ensemble simulation
gmx(
    executable = "energy",
    arguments = [],
    inputs = {
        "-f": "%s.edr" % ensemble
    },
    outputs = {
        "-o": "%s%s.xvg" % (ensemble, sufix)
    },
    stdin = "%d 0\n" % measure, 
    path = "%s" % (basepath)
)

# Generate the display the corresponding plots
xvg(title = "NPT Equilibration",
    path = basepath,
    ensemble = ensemble,
    xlabel = "Time (ps)",
    ylabel = "Density ($Kg\\cdot m^{-3}$)",
    label = "Density",
    sufix = sufix,
    movavg = 10
    )
# Out:
# <table><td><img src="U48800/rest/water/npt_d.png?1721132121.6081579" style="width:100%"></td></table>

# %% [markdown]
# #### REST2 setup

# %%
# Prepare the system for replica exchange with solute tempering (NPT)
presembl = "npt" # Previous ensemble
ensemble = "mds" # Ensemble

# Copy the parameter file to the directory
os.system("cp %s/%s.mdp %s" % (parapath, ensemble, basepath))

# Compile a regular expression to match lines with the specified pattern
pattern = re.compile(r'^\s*\d+.*SOP')

# Process the file
with open("%s/%s.top"%(basepath, presembl), 'r') as infile, open("%s/%s.%s.top"%(basepath, presembl, mdscmode), 'w') as outfile:
    for line in infile:
        # Check if the line matches the pattern
        if pattern.search(line):
            # Perform the replacement operation
            modified_line = re.sub(r'(\s*\d*\s*)([a-z]*_\d+)(\s)(.*)', r'\1\2_\4', line)
            outfile.write(modified_line)
        else:
            outfile.write(line)

# %%
# Generate scaled topologies
# Create the directories for replicas if they do not exist
for i in range(1, replicas + 1):
    os.makedirs("%s/replica%02d" % (basepath, i), exist_ok = True)

for i in range(1, replicas + 1):
    print("plumed partial_tempering %0.3f < %s.%s.top > replica%02d/%s.top" % (lambda_value[i - 1], presembl, mdscmode, i, presembl))
    subprocess.run("plumed partial_tempering %0.3f < %s.%s.top > replica%02d/%s.top" % (lambda_value[i - 1], presembl, mdscmode, i, presembl), shell = True, cwd = basepath)
# Out:
# plumed partial_tempering 1.000 < npt.rest.top > replica01/npt.top
# plumed partial_tempering 0.928 < npt.rest.top > replica02/npt.top
# plumed partial_tempering 0.862 < npt.rest.top > replica03/npt.top
# plumed partial_tempering 0.800 < npt.rest.top > replica04/npt.top
# plumed partial_tempering 0.742 < npt.rest.top > replica05/npt.top
# plumed partial_tempering 0.689 < npt.rest.top > replica06/npt.top
# plumed partial_tempering 0.640 < npt.rest.top > replica07/npt.top
# plumed partial_tempering 0.594 < npt.rest.top > replica08/npt.top
# plumed partial_tempering 0.551 < npt.rest.top > replica09/npt.top
# plumed partial_tempering 0.511 < npt.rest.top > replica10/npt.top

# %% [markdown]
# #### MD simulation

# %%
# Define the ensemble
presembl = "npt" # Previous ensemble
ensemble = "mds" # Ensemble

# Prepare the system to run the simulation
for i in range(1, replicas + 1):

    # Generate plumed file
    with open('%s/replica%02d/plumed.dat' % (basepath, i), 'w') as file:
        pass

    # Copy required files to the directory
    os.system("cp %s/%s.mdp %s/replica%02d/" % (basepath, ensemble, basepath, i))
    os.system("cp %s/%s.gro %s/replica%02d/" % (basepath, presembl, basepath, i))

    # Prepare the system to run the simulation
    gmx(
        executable = "grompp",
        arguments = [
            "-maxwarn", "2"                              # Maximum number of warnings (there is a warning relative to charge)
        ],
        inputs = {
            "-f": "%s.mdp" % ensemble,                   # Minimization parameters file
            "-c": "%s.gro" % presembl,                   # Input structure file
            "-p": "%s.top" % presembl     # Topology file
        },
        outputs = {
            "-po": "%s.mdp" % ensemble,                  # Output parameters file
            "-pp": "%s.top" % ensemble,                 # Output topology file
            "-o" : "%s.tpr" % ensemble                   # Output portable xdr run input file
        },
        path = "%s/replica%02d" % (basepath, i)
    )
# Out:
# Setting the LD random seed to -984081
#
# Generated 4851 of the 4851 non-bonded parameter combinations
#
# Generated 4851 of the 4851 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'SOP'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:     1      Other residues
# There are:  1018      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# The largest distance between excluded atoms is 0.402 nm between atom 20 and 22
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 293.15 K
#
# Calculated rlist for 1x1 atom pair-list as 1.213 nm, buffer size 0.013 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.112 0.112 0.112
#
# Estimate for the relative computational load of the PME mesh part: 0.09
#
# This run will generate roughly 708 Mb of data
#
#              :-) GROMACS - gmx grompp, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water/replica01
# Command line:
#   gmx grompp -maxwarn 2 -f mds.mdp -c npt.gro -p npt.top -po mds.mdp -pp mds.top -o mds.tpr
#
# Generating 1-4 interactions: fudge = 0.5
#
# NOTE 1 [file npt.top, line 621]:
#   System has non-zero total charge: 0.000400
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 1 [file npt.top, line 621]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
# Number of degrees of freedom in T-Coupling group System is 7237.00
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "An expert is a person who has made all the mistakes that can be made in a very narrow field." (Niels Bohr)
#
#
# Setting the LD random seed to -202526977
#
# Generated 4851 of the 4851 non-bonded parameter combinations
#
# Generated 4851 of the 4851 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'SOP'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:     1      Other residues
# There are:  1018      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# The largest distance between excluded atoms is 0.402 nm between atom 20 and 22
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 293.15 K
#
# Calculated rlist for 1x1 atom pair-list as 1.213 nm, buffer size 0.013 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.112 0.112 0.112
#
# Estimate for the relative computational load of the PME mesh part: 0.09
#
# This run will generate roughly 708 Mb of data
#
#              :-) GROMACS - gmx grompp, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water/replica02
# Command line:
#   gmx grompp -maxwarn 2 -f mds.mdp -c npt.gro -p npt.top -po mds.mdp -pp mds.top -o mds.tpr
#
# Generating 1-4 interactions: fudge = 0.5
#
# NOTE 1 [file npt.top, line 621]:
#   System has non-zero total charge: 0.000384
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 1 [file npt.top, line 621]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
# Number of degrees of freedom in T-Coupling group System is 7237.00
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "An expert is a person who has made all the mistakes that can be made in a very narrow field." (Niels Bohr)
#
#
# Setting the LD random seed to -8441932
#
# Generated 4851 of the 4851 non-bonded parameter combinations
#
# Generated 4851 of the 4851 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'SOP'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:     1      Other residues
# There are:  1018      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# The largest distance between excluded atoms is 0.402 nm between atom 20 and 22
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 293.15 K
#
# Calculated rlist for 1x1 atom pair-list as 1.213 nm, buffer size 0.013 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.112 0.112 0.112
#
# Estimate for the relative computational load of the PME mesh part: 0.09
#
# This run will generate roughly 708 Mb of data
#
#              :-) GROMACS - gmx grompp, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water/replica03
# Command line:
#   gmx grompp -maxwarn 2 -f mds.mdp -c npt.gro -p npt.top -po mds.mdp -pp mds.top -o mds.tpr
#
# Generating 1-4 interactions: fudge = 0.5
#
# NOTE 1 [file npt.top, line 621]:
#   System has non-zero total charge: 0.000371
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 1 [file npt.top, line 621]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
# Number of degrees of freedom in T-Coupling group System is 7237.00
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "An expert is a person who has made all the mistakes that can be made in a very narrow field." (Niels Bohr)
#
#
# Setting the LD random seed to 1558631878
#
# Generated 4851 of the 4851 non-bonded parameter combinations
#
# Generated 4851 of the 4851 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'SOP'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:     1      Other residues
# There are:  1018      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# The largest distance between excluded atoms is 0.402 nm between atom 20 and 22
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 293.15 K
#
# Calculated rlist for 1x1 atom pair-list as 1.213 nm, buffer size 0.013 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.112 0.112 0.112
#
# Estimate for the relative computational load of the PME mesh part: 0.09
#
# This run will generate roughly 708 Mb of data
#
#              :-) GROMACS - gmx grompp, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water/replica04
# Command line:
#   gmx grompp -maxwarn 2 -f mds.mdp -c npt.gro -p npt.top -po mds.mdp -pp mds.top -o mds.tpr
#
# Generating 1-4 interactions: fudge = 0.5
#
# NOTE 1 [file npt.top, line 621]:
#   System has non-zero total charge: 0.000357
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 1 [file npt.top, line 621]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
# Number of degrees of freedom in T-Coupling group System is 7237.00
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "An expert is a person who has made all the mistakes that can be made in a very narrow field." (Niels Bohr)
#
#
# Setting the LD random seed to -166839505
#
# Generated 4851 of the 4851 non-bonded parameter combinations
#
# Generated 4851 of the 4851 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'SOP'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:     1      Other residues
# There are:  1018      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# The largest distance between excluded atoms is 0.402 nm between atom 20 and 22
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 293.15 K
#
# Calculated rlist for 1x1 atom pair-list as 1.213 nm, buffer size 0.013 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.112 0.112 0.112
#
# Estimate for the relative computational load of the PME mesh part: 0.09
#
# This run will generate roughly 708 Mb of data
#
#              :-) GROMACS - gmx grompp, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water/replica05
# Command line:
#   gmx grompp -maxwarn 2 -f mds.mdp -c npt.gro -p npt.top -po mds.mdp -pp mds.top -o mds.tpr
#
# Generating 1-4 interactions: fudge = 0.5
#
# NOTE 1 [file npt.top, line 621]:
#   System has non-zero total charge: 0.000344
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 1 [file npt.top, line 621]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
# Number of degrees of freedom in T-Coupling group System is 7237.00
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "An expert is a person who has made all the mistakes that can be made in a very narrow field." (Niels Bohr)
#
#
# Setting the LD random seed to -35410565
#
# Generated 4851 of the 4851 non-bonded parameter combinations
#
# Generated 4851 of the 4851 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'SOP'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:     1      Other residues
# There are:  1018      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# The largest distance between excluded atoms is 0.402 nm between atom 20 and 22
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 293.15 K
#
# Calculated rlist for 1x1 atom pair-list as 1.213 nm, buffer size 0.013 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.112 0.112 0.112
#
# Estimate for the relative computational load of the PME mesh part: 0.09
#
# This run will generate roughly 708 Mb of data
#
#              :-) GROMACS - gmx grompp, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water/replica06
# Command line:
#   gmx grompp -maxwarn 2 -f mds.mdp -c npt.gro -p npt.top -po mds.mdp -pp mds.top -o mds.tpr
#
# Generating 1-4 interactions: fudge = 0.5
#
# NOTE 1 [file npt.top, line 621]:
#   System has non-zero total charge: 0.000332
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 1 [file npt.top, line 621]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
# Number of degrees of freedom in T-Coupling group System is 7237.00
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "I love fools' experiments. I am always making them." (Charles Darwin)
#
#
# Setting the LD random seed to -89166372
#
# Generated 4851 of the 4851 non-bonded parameter combinations
#
# Generated 4851 of the 4851 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'SOP'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:     1      Other residues
# There are:  1018      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# The largest distance between excluded atoms is 0.402 nm between atom 20 and 22
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 293.15 K
#
# Calculated rlist for 1x1 atom pair-list as 1.213 nm, buffer size 0.013 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.112 0.112 0.112
#
# Estimate for the relative computational load of the PME mesh part: 0.09
#
# This run will generate roughly 708 Mb of data
#
#              :-) GROMACS - gmx grompp, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water/replica07
# Command line:
#   gmx grompp -maxwarn 2 -f mds.mdp -c npt.gro -p npt.top -po mds.mdp -pp mds.top -o mds.tpr
#
# Generating 1-4 interactions: fudge = 0.5
#
# NOTE 1 [file npt.top, line 621]:
#   System has non-zero total charge: 0.000320
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 1 [file npt.top, line 621]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
# Number of degrees of freedom in T-Coupling group System is 7237.00
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "I love fools' experiments. I am always making them." (Charles Darwin)
#
#
# Setting the LD random seed to 2075828139
#
# Generated 4851 of the 4851 non-bonded parameter combinations
#
# Generated 4851 of the 4851 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'SOP'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:     1      Other residues
# There are:  1018      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# The largest distance between excluded atoms is 0.402 nm between atom 20 and 22
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 293.15 K
#
# Calculated rlist for 1x1 atom pair-list as 1.213 nm, buffer size 0.013 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.112 0.112 0.112
#
# Estimate for the relative computational load of the PME mesh part: 0.09
#
# This run will generate roughly 708 Mb of data
#
#              :-) GROMACS - gmx grompp, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water/replica08
# Command line:
#   gmx grompp -maxwarn 2 -f mds.mdp -c npt.gro -p npt.top -po mds.mdp -pp mds.top -o mds.tpr
#
# Generating 1-4 interactions: fudge = 0.5
#
# NOTE 1 [file npt.top, line 621]:
#   System has non-zero total charge: 0.000308
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 1 [file npt.top, line 621]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
# Number of degrees of freedom in T-Coupling group System is 7237.00
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "I love fools' experiments. I am always making them." (Charles Darwin)
#
#
# Setting the LD random seed to -1624506537
#
# Generated 4851 of the 4851 non-bonded parameter combinations
#
# Generated 4851 of the 4851 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'SOP'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:     1      Other residues
# There are:  1018      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# The largest distance between excluded atoms is 0.402 nm between atom 20 and 22
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 293.15 K
#
# Calculated rlist for 1x1 atom pair-list as 1.213 nm, buffer size 0.013 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.112 0.112 0.112
#
# Estimate for the relative computational load of the PME mesh part: 0.09
#
# This run will generate roughly 708 Mb of data
#
#              :-) GROMACS - gmx grompp, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water/replica09
# Command line:
#   gmx grompp -maxwarn 2 -f mds.mdp -c npt.gro -p npt.top -po mds.mdp -pp mds.top -o mds.tpr
#
# Generating 1-4 interactions: fudge = 0.5
#
# NOTE 1 [file npt.top, line 621]:
#   System has non-zero total charge: 0.000297
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 1 [file npt.top, line 621]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
# Number of degrees of freedom in T-Coupling group System is 7237.00
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "I love fools' experiments. I am always making them." (Charles Darwin)
#
#
# Setting the LD random seed to -216154189
#
# Generated 4851 of the 4851 non-bonded parameter combinations
#
# Generated 4851 of the 4851 1-4 parameter combinations
#
# Excluding 3 bonded neighbours molecule type 'SOP'
#
# turning H bonds into constraints...
#
# Excluding 2 bonded neighbours molecule type 'SOL'
#
# turning H bonds into constraints...
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# J. S. Hub, B. L. de Groot, H. Grubmueller, G. Groenhof
# Quantifying Artifacts in Ewald Simulations of Inhomogeneous Systems with a Net
# Charge
# J. Chem. Theory Comput. 10 (2014) pp. 381-393
# -------- -------- --- Thank You --- -------- --------
#
#
# Cleaning up constraints and constant bonded interactions with virtual sites
# Analysing residue names:
# There are:     1      Other residues
# There are:  1018      Water residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
#
# The largest distance between excluded atoms is 0.402 nm between atom 20 and 22
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 293.15 K
#
# Calculated rlist for 1x1 atom pair-list as 1.213 nm, buffer size 0.013 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.200 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 28x28x28, spacing 0.112 0.112 0.112
#
# Estimate for the relative computational load of the PME mesh part: 0.09
#
# This run will generate roughly 708 Mb of data
#
#              :-) GROMACS - gmx grompp, 2023.5-plumed_2.10.0_dev (-:
#
# Executable:   /opt/gromacs-2023.5-plumed/bin/gmx
# Data prefix:  /opt/gromacs-2023.5-plumed
# Working dir:  /home/familia/research/synthetic_opioids/U48800/rest/water/replica10
# Command line:
#   gmx grompp -maxwarn 2 -f mds.mdp -c npt.gro -p npt.top -po mds.mdp -pp mds.top -o mds.tpr
#
# Generating 1-4 interactions: fudge = 0.5
#
# NOTE 1 [file npt.top, line 621]:
#   System has non-zero total charge: 0.000286
#   Total charge should normally be an integer. See
#   https://manual.gromacs.org/current/user-guide/floating-point.html
#   for discussion on how close it should be to an integer.
#
#
#
#
# WARNING 1 [file npt.top, line 621]:
#   You are using Ewald electrostatics in a system with net charge. This can
#   lead to severe artifacts, such as ions moving into regions with low
#   dielectric, due to the uniform background charge. We suggest to
#   neutralize your system with counter ions, possibly in combination with a
#   physiological salt concentration.
#
# Number of degrees of freedom in T-Coupling group System is 7237.00
#
# There was 1 NOTE
#
# There was 1 WARNING
#
# GROMACS reminds you: "I love fools' experiments. I am always making them." (Charles Darwin)

# %%
# Run the simulation
gmx(
    executable = "mdrun",
    ensemble = ensemble,
    arguments = [
        "-v",                                      # Verbose output
        "-plumed", "plumed.dat",                   # Plumed file
        "-deffnm", ensemble,                       # Input and output file name prefix
        "-multidir", "replica01", "replica02",     # Replica directories
        "replica03", "replica04", "replica05",
        "replica06", "replica07", "replica08",
        "replica09", "replica10", 
        "-replex","1000",
        "-hrex",
        "-cpt", "15",                              # Save state every 15 minutes
        "-cpo", "mds.cpt",                         # Checkpoint file
        "-dlb", "auto"                             # Dynamic load balancing auto
    ],
    inputs = {},
    outputs = {},
    scheduler = {"ntasks":"10",
                 "ntasks-per-node":"1"},
    name = compound,
    path = basepath, 
    wait = False
)
# Out:
# Submitted batch job 389

# %%
# # Resume the simulation
# gmx(
#     executable = "mdrun",
#     ensemble = ensemble,
#     arguments = [
#         "-v",                                      # Verbose output
#         "-plumed", "plumed.dat",                   # Plumed file
#         "-deffnm", ensemble,                       # Input and output file name prefix
#         "-multidir", "replica01", "replica02",     # Replica directories
#         "replica03", "replica04", "replica05",
#         "replica06", "replica07", "replica08", 
#         "replica09", "replica10",
#         "-replex","1000",
#         "-hrex",
#         "-cpt", "15",                              # Save state every 15 minutes
#         "-cpo", "mds.cpt",                         # Checkpoint file
#     ],
#     inputs = {
#         "-cpi": "%s.cpt" % ensemble                # Resume from checkpoint file
#     },
#     outputs = {},
#     scheduler = {"ntasks":"10",
#                  "ntasks-per-node":"1"},
#     name = compound,
#     path = basepath, 
#     wait = False
# )
# Out:
# Submitted batch job 392

# %%
# Generate the pressure xvg file
measure = 11     # Potential energy
sufix = "_e"

#Compute the the selected parameter from the ensemble simulation
for i in range(1, replicas + 1):
    gmx(
        executable = "energy",
        arguments = [],
        inputs = {
            "-f": "%s.edr" % ensemble
        },
        outputs = {
            "-o": "%s%s.xvg" % (ensemble, sufix)
        },
        stdin = "%d 0\n" % measure, 
        path = "%s/replica%02d/" % (basepath, i)
    )

# Generate the display the corresponding plots
xvg(title = "Molecular Dynamics Simulation",
    measure = "$\\lambda$",
    values = lambda_value,
    units="",
    replicas = replicas,
    path = basepath,
    ensemble = ensemble,
    xlabel = "Time (ps)",
    ylabel = "Energy ($kJ\\cdot mol^{-1}$)",
    label = "Potential Energy",
    sufix = sufix,
    movavg = 100
)
# Out:
# <table><td><img src="U48800/rest/water/replica01/mds_e.png?1720711850.063457" style="width:100%"></td><td><img src="U48800/rest/water/replica02/mds_e.png?1720711852.217203" style="width:100%"></td><td><img src="U48800/rest/water/replica03/mds_e.png?1720711854.06496" style="width:100%"></td></tr><td><img src="U48800/rest/water/replica04/mds_e.png?1720711855.955621" style="width:100%"></td><td><img src="U48800/rest/water/replica05/mds_e.png?1720711857.768312" style="width:100%"></td><td><img src="U48800/rest/water/replica06/mds_e.png?1720711860.293366" style="width:100%"></td></tr><td><img src="U48800/rest/water/replica07/mds_e.png?1720711862.914062" style="width:100%"></td><td><img src="U48800/rest/water/replica08/mds_e.png?1720711864.890326" style="width:100%"></td><td><img src="U48800/rest/water/replica09/mds_e.png?1720711867.721947" style="width:100%"></td></tr></table>

# %%
# Generate the pressure xvg file
measure = 15     # Temperature
sufix = "_t"

# Compute the the selected parameter from the ensemble simulation
for i in range(1, replicas + 1):
    gmx(
        executable = "energy",
        arguments = [],
        inputs = {
            "-f": "%s.edr" % ensemble
        },
        outputs = {
            "-o": "%s%s.xvg" % (ensemble, sufix)
        },
        stdin = "%d 0\n" % measure, 
        path = "%s/replica%02d/" % (basepath, i)
    )

# Generate the display the corresponding plots
xvg(title = "Molecular Dynamics Simulation",
    measure = "$\\lambda$",
    values = lambda_value,
    units="",
    replicas = replicas,
    path = basepath,
    ensemble = ensemble,
    xlabel = "Time (ps)",
    ylabel = "Temperature (K)",
    label = "Temperature",
    sufix = sufix,
    movavg = 100
)
# Out:
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                 293.134      0.034    4.84768   0.113766  (K)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica01
# Command line:
#   gmx energy -f mds.edr -o mds_t.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "Physics isn't a religion. If it were, we'd have a much easier time raising money." (Leon Lederman)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                 293.154      0.025    4.82455  -0.109348  (K)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica02
# Command line:
#   gmx energy -f mds.edr -o mds_t.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "Physics isn't a religion. If it were, we'd have a much easier time raising money." (Leon Lederman)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                 293.151      0.029    4.83443   0.153349  (K)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica03
# Command line:
#   gmx energy -f mds.edr -o mds_t.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "I Need a Little Poison" (Throwing Muses)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                 293.189      0.019    4.83793   0.058618  (K)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica04
# Command line:
#   gmx energy -f mds.edr -o mds_t.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "I Need a Little Poison" (Throwing Muses)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                 293.171      0.015    4.84996  0.0751672  (K)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica05
# Command line:
#   gmx energy -f mds.edr -o mds_t.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "I Need a Little Poison" (Throwing Muses)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                  293.16      0.021    4.84059  0.0323789  (K)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica06
# Command line:
#   gmx energy -f mds.edr -o mds_t.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "I Need a Little Poison" (Throwing Muses)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                  293.13      0.015    4.85236  0.0963238  (K)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica07
# Command line:
#   gmx energy -f mds.edr -o mds_t.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "RTFM" (B. Hess)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                 293.126      0.018    4.84886  0.0850642  (K)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica08
# Command line:
#   gmx energy -f mds.edr -o mds_t.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "RTFM" (B. Hess)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                 293.134      0.011    4.85706 -0.0204467  (K)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica09
# Command line:
#   gmx energy -f mds.edr -o mds_t.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "RTFM" (B. Hess)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                 293.184      0.028    4.85981   0.105633  (K)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica10
# Command line:
#   gmx energy -f mds.edr -o mds_t.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "RTFM" (B. Hess)
# <table><td><img src="U48800/rest/water/replica01/mds_t.png?1720712023.256208" style="width:100%"></td><td><img src="U48800/rest/water/replica02/mds_t.png?1720712026.49646" style="width:100%"></td><td><img src="U48800/rest/water/replica03/mds_t.png?1720712028.479754" style="width:100%"></td></tr><td><img src="U48800/rest/water/replica04/mds_t.png?1720712030.1637719" style="width:100%"></td><td><img src="U48800/rest/water/replica05/mds_t.png?1720712033.2100859" style="width:100%"></td><td><img src="U48800/rest/water/replica06/mds_t.png?1720712037.8112571" style="width:100%"></td></tr><td><img src="U48800/rest/water/replica07/mds_t.png?1720712040.275722" style="width:100%"></td><td><img src="U48800/rest/water/replica08/mds_t.png?1720712041.8763788" style="width:100%"></td><td><img src="U48800/rest/water/replica09/mds_t.png?1720712043.82011" style="width:100%"></td></tr></table>

# %%
# Generate the pressure xvg file
measure = 17     # Pressure
sufix = "_p"

# Compute the the selected parameter from the ensemble simulation
for i in range(1, replicas + 1):
    gmx(
        executable = "energy",
        arguments = [],
        inputs = {
            "-f": "%s.edr" % ensemble
        },
        outputs = {
            "-o": "%s%s.xvg" % (ensemble, sufix)
        },
        stdin = "%d 0\n" % measure, 
        path = "%s/replica%02d/" % (basepath, i)
    )

# Generate the display the corresponding plots
xvg(title = "Molecular Dynamics Simulation",
    measure = "$\\lambda$",
    values = lambda_value,
    units="",
    replicas = replicas,
    path = basepath,
    ensemble = ensemble,
    xlabel = "Time (ps)",
    ylabel = "Pressure (bar)",
    label = "Pressure",
    sufix = sufix,
    movavg = 100
)
# Out:
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                   0.853655        1.8    420.236  -0.998641  (bar)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica01
# Command line:
#   gmx energy -f mds.edr -o mds_p.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "Love is Like Moby Dick, Get Chewed and Get Spat Out" (Urban Dance Squad)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                    1.78537        1.1    420.285     -6.146  (bar)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica02
# Command line:
#   gmx energy -f mds.edr -o mds_p.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "Count the Bubbles In Your Hair" (The Breeders)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                  -0.732823       0.71     420.63    3.49804  (bar)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica03
# Command line:
#   gmx energy -f mds.edr -o mds_p.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "Count the Bubbles In Your Hair" (The Breeders)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                    3.95587        1.1     420.26    2.01507  (bar)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica04
# Command line:
#   gmx energy -f mds.edr -o mds_p.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "Count the Bubbles In Your Hair" (The Breeders)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                   0.255375        2.6     418.95    10.4452  (bar)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica05
# Command line:
#   gmx energy -f mds.edr -o mds_p.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "You Look Better Upside Down" (Throwing Muses)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                    2.57656          1    418.329   -5.15731  (bar)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica06
# Command line:
#   gmx energy -f mds.edr -o mds_p.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "You Look Better Upside Down" (Throwing Muses)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                    2.47131        1.3    419.333  -0.335344  (bar)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica07
# Command line:
#   gmx energy -f mds.edr -o mds_p.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "It's Unacceptable That Chocolate Makes You Fat" (MI 3)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                  -0.122884        1.6    418.397    7.03298  (bar)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica08
# Command line:
#   gmx energy -f mds.edr -o mds_p.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "It's Unacceptable That Chocolate Makes You Fat" (MI 3)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                     3.1654        1.6     417.76     6.2205  (bar)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica09
# Command line:
#   gmx energy -f mds.edr -o mds_p.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "It's Unacceptable That Chocolate Makes You Fat" (MI 3)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                 -0.0256132          2     417.76    2.06736  (bar)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica10
# Command line:
#   gmx energy -f mds.edr -o mds_p.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "With a Lead Filled Snowshoe" (F. Zappa)
# <table><td><img src="U48800/rest/water/replica01/mds_p.png?1720712135.581085" style="width:100%"></td><td><img src="U48800/rest/water/replica02/mds_p.png?1720712137.2970738" style="width:100%"></td><td><img src="U48800/rest/water/replica03/mds_p.png?1720712138.9023721" style="width:100%"></td></tr><td><img src="U48800/rest/water/replica04/mds_p.png?1720712140.64348" style="width:100%"></td><td><img src="U48800/rest/water/replica05/mds_p.png?1720712142.260554" style="width:100%"></td><td><img src="U48800/rest/water/replica06/mds_p.png?1720712143.861259" style="width:100%"></td></tr><td><img src="U48800/rest/water/replica07/mds_p.png?1720712145.806409" style="width:100%"></td><td><img src="U48800/rest/water/replica08/mds_p.png?1720712147.495544" style="width:100%"></td><td><img src="U48800/rest/water/replica09/mds_p.png?1720712149.136564" style="width:100%"></td></tr></table>

# %%
# Generate the density xvg file
measure = 23     # Density
sufix = "_d"

# Compute the the selected parameter from the ensemble simulation
for i in range(1, replicas + 1):
    gmx(
        executable = "energy",
        arguments = [],
        inputs = {
            "-f": "%s.edr" % ensemble
        },
        outputs = {
            "-o": "%s%s.xvg" % (ensemble, sufix)
        },
        stdin = "%d 0\n" % measure, 
        path = "%s/replica%02d/" % (basepath, i)
    )

# Generate the display the corresponding plots
xvg(title = "Molecular Dynamics Simulation",
    measure = "$\\lambda$",
    values = lambda_value,
    units="",
    replicas = replicas,
    path = basepath,
    ensemble = ensemble,
    xlabel = "Time (ps)",
    ylabel = "Density ($Kg\\cdot m^{-3}$)",
    label = "Density",
    sufix = sufix,
    movavg = 100
)
# Out:
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                     1003.99      0.063    8.05525  -0.132554  (kg/m^3)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica01
# Command line:
#   gmx energy -f mds.edr -o mds_d.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "Do the Dog On the Ground" (Red Hot Chili Peppers)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                     1003.76      0.054    8.20317 -0.0851913  (kg/m^3)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica02
# Command line:
#   gmx energy -f mds.edr -o mds_d.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "Do the Dog On the Ground" (Red Hot Chili Peppers)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                     1003.47      0.019    8.29947  0.0221705  (kg/m^3)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica03
# Command line:
#   gmx energy -f mds.edr -o mds_d.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "Do the Dog On the Ground" (Red Hot Chili Peppers)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                     1003.47       0.11    8.16367   0.591688  (kg/m^3)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica04
# Command line:
#   gmx energy -f mds.edr -o mds_d.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "I love deadlines. I like the whooshing sound they make as they fly by." (Douglas Adams)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                     1003.16       0.11    8.18211   0.402999  (kg/m^3)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica05
# Command line:
#   gmx energy -f mds.edr -o mds_d.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "I love deadlines. I like the whooshing sound they make as they fly by." (Douglas Adams)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                     1002.88      0.082    8.08222  -0.419924  (kg/m^3)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica06
# Command line:
#   gmx energy -f mds.edr -o mds_d.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "I love deadlines. I like the whooshing sound they make as they fly by." (Douglas Adams)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                      1002.8      0.056    8.19466  -0.256616  (kg/m^3)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica07
# Command line:
#   gmx energy -f mds.edr -o mds_d.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "Please implement proper hep writing" (GROMACS)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                     1002.69      0.088    8.15739   0.162193  (kg/m^3)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica08
# Command line:
#   gmx energy -f mds.edr -o mds_d.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "Please implement proper hep writing" (GROMACS)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                     1002.63      0.056    8.20692   0.381934  (kg/m^3)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica09
# Command line:
#   gmx energy -f mds.edr -o mds_d.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "Please implement proper hep writing" (GROMACS)
#
#
#
# Statistics over 10000001 steps [ 0.0000 through 10000.0000 ps ], 1 data sets
# All statistics are over 100001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                     1002.44      0.092    8.10182   0.138287  (kg/m^3)
#
#                       :-) GROMACS - gmx energy, 2024.1 (-:
#
# Executable:   /opt/local/bin/gmx
# Data prefix:  /opt/local
# Working dir:  /Users/familia/Documents/Research/projects/synthetic_opioids_structure/U48800/rest/water/replica10
# Command line:
#   gmx energy -f mds.edr -o mds_d.xvg
#
# Opened mds.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  Ryckaert-Bell.   4  Per.-Imp.-Dih.
#   5  LJ-14            6  Coulomb-14       7  LJ-(SR)          8  Disper.-corr.
#   9  Coulomb-(SR)    10  Coul.-recip.    11  Potential       12  Kinetic-En.
#  13  Total-Energy    14  Conserved-En.   15  Temperature     16  Pres.-DC
#  17  Pressure        18  Constr.-rmsd    19  Box-X           20  Box-Y
#  21  Box-Z           22  Volume          23  Density         24  pV
#  25  Enthalpy        26  Vir-XX          27  Vir-XY          28  Vir-XZ
#  29  Vir-YX          30  Vir-YY          31  Vir-YZ          32  Vir-ZX
#  33  Vir-ZY          34  Vir-ZZ          35  Pres-XX         36  Pres-XY
#  37  Pres-XZ         38  Pres-YX         39  Pres-YY         40  Pres-YZ
#  41  Pres-ZX         42  Pres-ZY         43  Pres-ZZ         44  #Surf*SurfTen
#  45  T-System        46  Lamb-System
#
#
# Reading energy frame      0 time    0.000
# Reading energy frame      1 time    1.000
# Reading energy frame      2 time    2.000
# Reading energy frame      3 time    3.000
# Reading energy frame      4 time    4.000
# Reading energy frame      5 time    5.000
# Reading energy frame      6 time    6.000
# Reading energy frame      7 time    7.000
# Reading energy frame      8 time    8.000
# Reading energy frame      9 time    9.000
# Reading energy frame     10 time   10.000
# Reading energy frame     11 time   11.000
# Reading energy frame     12 time   12.000
# Reading energy frame     13 time   13.000
# Reading energy frame     14 time   14.000
# Reading energy frame     15 time   15.000
# Reading energy frame     16 time   16.000
# Reading energy frame     17 time   17.000
# Reading energy frame     18 time   18.000
# Reading energy frame     19 time   19.000
# Reading energy frame     20 time   20.000
# Reading energy frame     30 time   30.000
# Reading energy frame     40 time   40.000
# Reading energy frame     50 time   50.000
# Reading energy frame     60 time   60.000
# Reading energy frame     70 time   70.000
# Reading energy frame     80 time   80.000
# Reading energy frame     90 time   90.000
# Reading energy frame    100 time  100.000
# Reading energy frame    110 time  110.000
# Reading energy frame    120 time  120.000
# Reading energy frame    130 time  130.000
# Reading energy frame    140 time  140.000
# Reading energy frame    150 time  150.000
# Reading energy frame    160 time  160.000
# Reading energy frame    170 time  170.000
# Reading energy frame    180 time  180.000
# Reading energy frame    190 time  190.000
# Reading energy frame    200 time  200.000
# Reading energy frame    300 time  300.000
# Reading energy frame    400 time  400.000
# Reading energy frame    500 time  500.000
# Reading energy frame    600 time  600.000
# Reading energy frame    700 time  700.000
# Reading energy frame    800 time  800.000
# Reading energy frame    900 time  900.000
# Reading energy frame   1000 time 1000.000
# Reading energy frame   1100 time 1100.000
# Reading energy frame   1200 time 1200.000
# Reading energy frame   1300 time 1300.000
# Reading energy frame   1400 time 1400.000
# Reading energy frame   1500 time 1500.000
# Reading energy frame   1600 time 1600.000
# Reading energy frame   1700 time 1700.000
# Reading energy frame   1800 time 1800.000
# Reading energy frame   1900 time 1900.000
# Reading energy frame   2000 time 2000.000
# Reading energy frame   3000 time 3000.000
# Reading energy frame   4000 time 4000.000
# Reading energy frame   5000 time 5000.000
# Reading energy frame   6000 time 6000.000
# Reading energy frame   7000 time 7000.000
# Reading energy frame   8000 time 8000.000
# Reading energy frame   9000 time 9000.000
# Reading energy frame  10000 time 10000.000
# Last energy frame read 10000 time 10000.000
#
# GROMACS reminds you: "Expertise is not inherently good." (Joe Jordan)
# <table><td><img src="U48800/rest/water/replica01/mds_d.png?1721132310.827581" style="width:100%"></td><td><img src="U48800/rest/water/replica02/mds_d.png?1721132312.679757" style="width:100%"></td><td><img src="U48800/rest/water/replica03/mds_d.png?1721132314.8778539" style="width:100%"></td></tr><td><img src="U48800/rest/water/replica04/mds_d.png?1721132317.56648" style="width:100%"></td><td><img src="U48800/rest/water/replica05/mds_d.png?1721132320.5241249" style="width:100%"></td><td><img src="U48800/rest/water/replica06/mds_d.png?1721132323.143994" style="width:100%"></td></tr><td><img src="U48800/rest/water/replica07/mds_d.png?1721132325.034701" style="width:100%"></td><td><img src="U48800/rest/water/replica08/mds_d.png?1721132327.768398" style="width:100%"></td><td><img src="U48800/rest/water/replica09/mds_d.png?1721132330.235559" style="width:100%"></td></tr></table>
